# %%
from datetime import time
from decimal import Decimal

import pandas as pd

from nautilus_trader.adapters.databento.loaders import DatabentoDataLoader
from nautilus_trader.backtest.engine import BacktestEngine, BacktestEngineConfig
from nautilus_trader.common.enums import LogColor
from nautilus_trader.config import ExecAlgorithmConfig, LoggingConfig, PositiveInt, StrategyConfig
from nautilus_trader.core.correctness import PyCondition
from nautilus_trader.core.data import Data
from nautilus_trader.core.datetime import dt_to_unix_nanos, unix_nanos_to_dt
from nautilus_trader.core.message import Event
from nautilus_trader.execution.algorithm import ExecAlgorithm
from nautilus_trader.indicators.average.ema import ExponentialMovingAverage
from nautilus_trader.model.book import OrderBook
from nautilus_trader.model.currencies import USD
from nautilus_trader.model.data import Bar, BarType, OrderBookDeltas, QuoteTick, TradeTick
from nautilus_trader.model.enums import AccountType, BarAggregation, OmsType, OrderSide, TimeInForce
from nautilus_trader.model.identifiers import ExecAlgorithmId, InstrumentId, TraderId, Venue
from nautilus_trader.model.instruments import Instrument
from nautilus_trader.model.objects import Money
from nautilus_trader.model.orders import MarketOrder, Order, OrderList
from nautilus_trader.persistence.loaders import CSVBarDataLoader
from nautilus_trader.persistence.wranglers import BarDataWrangler
from nautilus_trader.test_kit.providers import TestInstrumentProvider
from nautilus_trader.trading.strategy import Strategy
from nautilus_trader.examples.strategies.ema_cross_long_only import EMACrossLongOnly, EMACrossLongOnlyConfig

# %%
class RangeBreakoutConfig(StrategyConfig):
    instrument_id: InstrumentId
    bar_type: BarType
    trade_size: Decimal
    range_start: time = time(16, 0)  # 16:00:00
    range_end: time = time(19, 0)    # 19:00:00
    exit_time: time = time(23, 59)   # 23:59:00
    profit_factor: float = 0.6      # Target multiplier
    loss_factor: float = 0.6        # Stop loss multiplier
    


class RangeBreakoutStrategy(Strategy):
    """
    A breakout strategy that trades based on price action relative to a time-based range.
    
    The strategy:
    1. Calculates high/low range between t1 (16:00) and t2 (19:00)
    2. After t2, enters long positions when price breaks above the range high
    3. Sets profit target and stop loss based on range size
    4. Exits any open position at t3 (23:59)
    """

    def __init__(self, config: RangeBreakoutConfig):
        super().__init__(config)
        
        # Configuration
        self.instrument_id = config.instrument_id
        self.bar_type = config.bar_type
        self.trade_size = config.trade_size
        self.range_start = config.range_start
        self.range_end = config.range_end
        self.exit_time = config.exit_time
        self.profit_factor = config.profit_factor
        self.loss_factor = config.loss_factor
        
        # Runtime variables
        self.instrument: Instrument = None
        self.range_high: float = None
        self.range_low: float = None
        self.in_range_building_time: bool = False
        self.range_built: bool = False
        self.position_opened: bool = False

    def on_start(self) -> None:
        """Actions to be performed on strategy start."""
        # Get instrument
        self.instrument = self.cache.instrument(self.instrument_id)
        if self.instrument is None:
            self.log.error(f"Could not find instrument for {self.instrument_id}")
            self.stop()
            return

        # Subscribe to bar data
        self.subscribe_bars(self.bar_type)

    def on_bar(self, bar: Bar) -> None:
        """
        Process incoming bars and implement trading logic.
        """
        # Skip bars with no price information
        if bar.is_single_price():
            return

        # bar_time = bar.timestamp.time()
        current_dt = unix_nanos_to_dt(bar.ts_init)
        bar_time = current_dt.time()
        
        # Check if we're in range building period
        if self.range_start <= bar_time < self.range_end:
            self.in_range_building_time = True
            
            # Update range high/low
            if self.range_high is None or bar.high.as_double() > self.range_high:
                self.range_high = bar.high.as_double()
            if self.range_low is None or bar.low.as_double() < self.range_low:
                self.range_low = bar.low.as_double()
                
        # Range building period is over
        elif bar_time >= self.range_end and self.in_range_building_time:
            self.in_range_building_time = False
            self.range_built = True
            self.log.info(
                f"Range built - High: {self.range_high}, Low: {self.range_low}",
                color=LogColor.CYAN,
            )
            
        # Trading period
        if self.range_built and not self.position_opened and bar_time >= self.range_end:
            # Check for breakout
            if bar.close.as_double() > self.range_high:
                self.enter_long_position(bar.close.as_double())
                
        # Check for exit time
        if bar_time >= self.exit_time:
            if self.portfolio.is_net_long(self.instrument_id):
                self.close_all_positions(self.instrument_id)
                self.log.info("Time exit executed", color=LogColor.YELLOW)
            
            # Reset for next day
            self.reset_daily_vars()

    def enter_long_position(self, entry_price: float) -> None:
        """Enter a long position and store target/stop prices for order handling."""
        range_size = self.range_high - self.range_low
        
        # Store prices for order handling
        self.pending_entry_price = entry_price
        self.pending_target_price = entry_price + (range_size * self.profit_factor)
        self.pending_stop_price = entry_price - (range_size * self.loss_factor)
        
        # Create and submit market order
        order = self.order_factory.market(
            instrument_id=self.instrument_id,
            order_side=OrderSide.BUY,
            quantity=self.instrument.make_qty(self.trade_size),
            time_in_force=TimeInForce.IOC,
        )

        self.submit_order(order)

    def on_order(self, order: Order) -> None:
        """
        Handles order status updates and places take profit/stop loss orders
        when entry is filled.
        """
        if order.status == OrderStatus.FILLED:
            if isinstance(order, MarketOrder) and order.side == OrderSide.BUY:
                # Entry order was filled, place take profit and stop loss
                if self.pending_target_price and self.pending_stop_price:
                    # Place take profit order
                    tp_order = self.order_factory.limit(
                        instrument_id=self.instrument_id,
                        order_side=OrderSide.SELL,
                        price=Price(self.pending_target_price),
                        quantity=order.quantity,
                        time_in_force=TimeInForce.GTC,
                    )
                    self.submit_order(tp_order)

                    # Place stop loss order
                    sl_order = self.order_factory.stop_market(
                        instrument_id=self.instrument_id,
                        order_side=OrderSide.SELL,
                        trigger_price=Price(self.pending_stop_price),
                        quantity=order.quantity,
                        time_in_force=TimeInForce.GTC,
                    )
                    self.submit_order(sl_order)

                    self.position_opened = True
                    self.log.info(
                        f"Long position opened - Entry: {self.pending_entry_price}, "
                        f"Target: {self.pending_target_price}, Stop: {self.pending_stop_price}",
                        color=LogColor.GREEN,
                    )

                    # Clear pending prices
                    self.pending_entry_price = None
                    self.pending_target_price = None
                    self.pending_stop_price = None

    def reset_daily_vars(self) -> None:
        """Reset variables for the next trading day."""
        self.range_high = None
        self.range_low = None
        self.in_range_building_time = False
        self.range_built = False
        self.position_opened = False
        self.pending_entry_price = None
        self.pending_target_price = None
        self.pending_stop_price = None
        

    def on_stop(self) -> None:
        """Actions to be performed when the strategy is stopped."""
        self.cancel_all_orders(self.instrument_id)
        self.close_all_positions(self.instrument_id)
        self.unsubscribe_bars(self.bar_type)

    def on_reset(self) -> None:
        """Actions to be performed when the strategy is reset."""
        self.reset_daily_vars()

    def on_save(self) -> dict[str, bytes]:
        """Save strategy state."""
        return {}

    def on_load(self, state: dict[str, bytes]) -> None:
        """Load strategy state."""
        pass

    def on_dispose(self) -> None:
        """Clean up resources."""
        pass

# %%
if __name__ == "__main__":
    config = BacktestEngineConfig(
        trader_id=TraderId("BACKTESTER-001"),
        logging=LoggingConfig(log_level="INFO"),
    )
    engine = BacktestEngine(config=config)

    NASDAQ = Venue("XNAS")

    engine.add_venue(
        venue=NASDAQ,
        oms_type=OmsType.NETTING,
        account_type=AccountType.CASH,
        base_currency=USD,
        starting_balances=[Money(1_000_000_000.0, USD)],
    )

    SPY_XNAS = TestInstrumentProvider.equity(symbol="NQ", venue="XNAS")
    engine.add_instrument(SPY_XNAS)
    instrument_id = SPY_XNAS.id

    bar_type = BarType.from_str(f"{instrument_id}-1-MINUTE-LAST-EXTERNAL")
    wrangler = BarDataWrangler(bar_type, SPY_XNAS)

    df = pd.read_csv("./Nasdaq_1min_v1.csv", index_col=0)
    df1 = df.copy()
    df1['timestamp'] = pd.to_datetime(df1['ts_event'])
    df1.set_index('timestamp', inplace=True)
    df1 = df1.iloc[:30000]

    bars = wrangler.process(
        df1[['open', 'high', 'low', 'close', 'volume']],
        ts_init_delta=60000000000
    )

    engine.add_data(bars)

    config = RangeBreakoutConfig(
        instrument_id=SPY_XNAS.id,
        bar_type=BarType.from_str(f"{SPY_XNAS.id}-1-MINUTE-LAST-EXTERNAL"), #BarAggregation.MINUTE,
        trade_size=Decimal("1"),
    )

# RangeBreakoutStrategy
# RangeBreakoutConfig
    # strategy = EMACrossLongOnly(config=config)
    # engine.add_strategy(strategy=strategy)

    strategy = RangeBreakoutStrategy(config=config)
    engine.add_strategy(strategy)

    engine.run()

# %%
account_report_df = engine.trader.generate_account_report(NASDAQ)
account_report_df
# Out:
#                                    total locked           free currency  \
# 2019-08-21 00:01:00+00:00  1000000000.00   0.00  1000000000.00      USD
# 2019-08-21 20:37:00+00:00   999992242.25   0.00   999992242.25      USD
# 2019-08-21 20:38:00+00:00   999984484.75   0.00   999984484.75      USD
# 2019-08-21 20:52:00+00:00   999976727.75   0.00   999976727.75      USD
# 2019-08-21 20:53:00+00:00   999968970.25   0.00   999968970.25      USD
# ...                                  ...    ...            ...      ...
# 2019-09-18 23:58:00+00:00   998798783.23   0.00   998798783.23      USD
# 2019-09-18 23:59:00+00:00   998790897.48   0.00   998790897.48      USD
# 2019-09-18 23:59:00+00:00   998798783.23   0.00   998798783.23      USD
# 2019-09-18 23:59:00+00:00   999989529.97   0.00   999989529.97      USD
# 2019-09-19 23:59:00+00:00   999997457.22   0.00   999997457.22      USD
#
#                           account_id account_type base_currency margins  \
# 2019-08-21 00:01:00+00:00   XNAS-001         CASH           USD      []
# 2019-08-21 20:37:00+00:00   XNAS-001         CASH           USD      []
# 2019-08-21 20:38:00+00:00   XNAS-001         CASH           USD      []
# 2019-08-21 20:52:00+00:00   XNAS-001         CASH           USD      []
# 2019-08-21 20:53:00+00:00   XNAS-001         CASH           USD      []
# ...                              ...          ...           ...     ...
# 2019-09-18 23:58:00+00:00   XNAS-001         CASH           USD      []
# 2019-09-18 23:59:00+00:00   XNAS-001         CASH           USD      []
# 2019-09-18 23:59:00+00:00   XNAS-001         CASH           USD      []
# 2019-09-18 23:59:00+00:00   XNAS-001         CASH           USD      []
# 2019-09-19 23:59:00+00:00   XNAS-001         CASH           USD      []
#
#                            reported info
# 2019-08-21 00:01:00+00:00      True   {}
# 2019-08-21 20:37:00+00:00     False   {}
# 2019-08-21 20:38:00+00:00     False   {}
# 2019-08-21 20:52:00+00:00     False   {}
# 2019-08-21 20:53:00+00:00     False   {}
# ...                             ...  ...
# 2019-09-18 23:58:00+00:00     False   {}
# 2019-09-18 23:59:00+00:00     False   {}
# 2019-09-18 23:59:00+00:00     False   {}
# 2019-09-18 23:59:00+00:00     False   {}
# 2019-09-19 23:59:00+00:00     False   {}
#
# [1160 rows x 10 columns]

# %%
order_fills_report_df = engine.trader.generate_order_fills_report()
order_fills_report_df
# Out:
#                                      trader_id                strategy_id  \
# client_order_id
# O-20190821-203700-001-000-1     BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190821-203800-001-000-2     BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190821-205200-001-000-3     BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190821-205300-001-000-4     BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190821-205400-001-000-5     BACKTESTER-001  RangeBreakoutStrategy-000
# ...                                        ...                        ...
# O-20190918-235700-001-000-1146  BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190918-235800-001-000-1147  BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190918-235900-001-000-1148  BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190918-235900-001-000-1149  BACKTESTER-001  RangeBreakoutStrategy-000
# O-20190919-235900-001-000-1150  BACKTESTER-001  RangeBreakoutStrategy-000
#
#                                instrument_id venue_order_id  \
# client_order_id
# O-20190821-203700-001-000-1          NQ.XNAS     XNAS-1-001
# O-20190821-203800-001-000-2          NQ.XNAS     XNAS-1-002
# O-20190821-205200-001-000-3          NQ.XNAS     XNAS-1-003
# O-20190821-205300-001-000-4          NQ.XNAS     XNAS-1-004
# O-20190821-205400-001-000-5          NQ.XNAS     XNAS-1-005
# ...                                      ...            ...
# O-20190918-235700-001-000-1146       NQ.XNAS    XNAS-1-1146
# O-20190918-235800-001-000-1147       NQ.XNAS    XNAS-1-1147
# O-20190918-235900-001-000-1148       NQ.XNAS    XNAS-1-1148
# O-20190918-235900-001-000-1149       NQ.XNAS    XNAS-1-1149
# O-20190919-235900-001-000-1150       NQ.XNAS    XNAS-1-1150
#
#                                                       position_id account_id  \
# client_order_id
# O-20190821-203700-001-000-1     NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190821-203800-001-000-2     NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190821-205200-001-000-3     NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190821-205300-001-000-4     NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190821-205400-001-000-5     NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# ...                                                           ...        ...
# O-20190918-235700-001-000-1146  NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190918-235800-001-000-1147  NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190918-235900-001-000-1148  NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190918-235900-001-000-1149  NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
# O-20190919-235900-001-000-1150  NQ.XNAS-RangeBreakoutStrategy-000   XNAS-001
#
#                                last_trade_id    type  side quantity  ...  \
# client_order_id                                                      ...
# O-20190821-203700-001-000-1      XNAS-1-1223  MARKET   BUY        1  ...
# O-20190821-203800-001-000-2      XNAS-1-1225  MARKET   BUY        1  ...
# O-20190821-205200-001-000-3      XNAS-1-1240  MARKET   BUY        1  ...
# O-20190821-205300-001-000-4      XNAS-1-1242  MARKET   BUY        1  ...
# O-20190821-205400-001-000-5      XNAS-1-1244  MARKET   BUY        1  ...
# ...                                      ...     ...   ...      ...  ...
# O-20190918-235700-001-000-1146  XNAS-1-29588  MARKET   BUY        1  ...
# O-20190918-235800-001-000-1147  XNAS-1-29590  MARKET   BUY        1  ...
# O-20190918-235900-001-000-1148  XNAS-1-29592  MARKET   BUY        1  ...
# O-20190918-235900-001-000-1149  XNAS-1-29594  MARKET  SELL      152  ...
# O-20190919-235900-001-000-1150  XNAS-1-30960  MARKET  SELL        1  ...
#
#                                order_list_id  linked_order_ids  \
# client_order_id
# O-20190821-203700-001-000-1             None              None
# O-20190821-203800-001-000-2             None              None
# O-20190821-205200-001-000-3             None              None
# O-20190821-205300-001-000-4             None              None
# O-20190821-205400-001-000-5             None              None
# ...                                      ...               ...
# O-20190918-235700-001-000-1146          None              None
# O-20190918-235800-001-000-1147          None              None
# O-20190918-235900-001-000-1148          None              None
# O-20190918-235900-001-000-1149          None              None
# O-20190919-235900-001-000-1150          None              None
#
#                                 parent_order_id exec_algorithm_id  \
# client_order_id
# O-20190821-203700-001-000-1                None              None
# O-20190821-203800-001-000-2                None              None
# O-20190821-205200-001-000-3                None              None
# O-20190821-205300-001-000-4                None              None
# O-20190821-205400-001-000-5                None              None
# ...                                         ...               ...
# O-20190918-235700-001-000-1146             None              None
# O-20190918-235800-001-000-1147             None              None
# O-20190918-235900-001-000-1148             None              None
# O-20190918-235900-001-000-1149             None              None
# O-20190919-235900-001-000-1150             None              None
#
#                                exec_algorithm_params exec_spawn_id  tags  \
# client_order_id
# O-20190821-203700-001-000-1                     None          None  None
# O-20190821-203800-001-000-2                     None          None  None
# O-20190821-205200-001-000-3                     None          None  None
# O-20190821-205300-001-000-4                     None          None  None
# O-20190821-205400-001-000-5                     None          None  None
# ...                                              ...           ...   ...
# O-20190918-235700-001-000-1146                  None          None  None
# O-20190918-235800-001-000-1147                  None          None  None
# O-20190918-235900-001-000-1148                  None          None  None
# O-20190918-235900-001-000-1149                  None          None  None
# O-20190919-235900-001-000-1150                  None          None  None
#
#                                                              init_id  \
# client_order_id
# O-20190821-203700-001-000-1     1f18d3ad-87fb-4cd4-8654-4a3e6076f4fe
# O-20190821-203800-001-000-2     c4dd8170-05b8-46ab-800f-fe872673e568
# O-20190821-205200-001-000-3     d752d0f4-5c10-4700-ad89-5a95df5301cd
# O-20190821-205300-001-000-4     580a2c5a-c99f-47f9-a475-e3208f5f4af3
# O-20190821-205400-001-000-5     32d47751-0e1a-4942-980a-a2ef3d2b1970
# ...                                                              ...
# O-20190918-235700-001-000-1146  1f2825a2-62c3-4f3b-b90a-53d75f7c4167
# O-20190918-235800-001-000-1147  cc3dffe6-d22f-44ba-91bb-9eb586733e70
# O-20190918-235900-001-000-1148  2a4ae3a0-a0cd-4a94-ad59-c3565b9474c2
# O-20190918-235900-001-000-1149  53a6f5ca-db64-4dfe-8776-7259ea6d762c
# O-20190919-235900-001-000-1150  4a66cb97-2598-4080-96b1-38a6ea5aa0ae
#
#                                                  ts_init  \
# client_order_id
# O-20190821-203700-001-000-1    2019-08-21 20:37:00+00:00
# O-20190821-203800-001-000-2    2019-08-21 20:38:00+00:00
# O-20190821-205200-001-000-3    2019-08-21 20:52:00+00:00
# O-20190821-205300-001-000-4    2019-08-21 20:53:00+00:00
# O-20190821-205400-001-000-5    2019-08-21 20:54:00+00:00
# ...                                                  ...
# O-20190918-235700-001-000-1146 2019-09-18 23:57:00+00:00
# O-20190918-235800-001-000-1147 2019-09-18 23:58:00+00:00
# O-20190918-235900-001-000-1148 2019-09-18 23:59:00+00:00
# O-20190918-235900-001-000-1149 2019-09-18 23:59:00+00:00
# O-20190919-235900-001-000-1150 2019-09-19 23:59:00+00:00
#
#                                                  ts_last
# client_order_id
# O-20190821-203700-001-000-1    2019-08-21 20:37:00+00:00
# O-20190821-203800-001-000-2    2019-08-21 20:38:00+00:00
# O-20190821-205200-001-000-3    2019-08-21 20:52:00+00:00
# O-20190821-205300-001-000-4    2019-08-21 20:53:00+00:00
# O-20190821-205400-001-000-5    2019-08-21 20:54:00+00:00
# ...                                                  ...
# O-20190918-235700-001-000-1146 2019-09-18 23:57:00+00:00
# O-20190918-235800-001-000-1147 2019-09-18 23:58:00+00:00
# O-20190918-235900-001-000-1148 2019-09-18 23:59:00+00:00
# O-20190918-235900-001-000-1149 2019-09-18 23:59:00+00:00
# O-20190919-235900-001-000-1150 2019-09-19 23:59:00+00:00
#
# [1150 rows x 31 columns]

# %%
positions_report_df = engine.trader.generate_positions_report()
positions_report_df
# Out:
#                                                          trader_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000                   BACKTESTER-001
#
#                                                                   strategy_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000                   RangeBreakoutStrategy-000
#
#                                                    instrument_id account_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000                        NQ.XNAS   XNAS-001
#
#                                                                  opening_order_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...    O-20190821-203700-001-000-1
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  O-20190826-200000-001-000-131
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  O-20190827-190300-001-000-255
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  O-20190828-192000-001-000-264
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  O-20190902-225500-001-000-268
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  O-20190904-192500-001-000-274
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  O-20190910-200100-001-000-556
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  O-20190911-203800-001-000-628
# NQ.XNAS-RangeBreakoutStrategy-000                   O-20190916-200300-001-000-694
#
#                                                                   closing_order_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   O-20190822-235900-001-000-130
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...   O-20190826-235900-001-000-254
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...   O-20190827-235900-001-000-263
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...   O-20190828-235900-001-000-267
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...   O-20190902-235900-001-000-273
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...   O-20190908-235900-001-000-555
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   O-20190910-235900-001-000-627
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   O-20190912-235900-001-000-693
# NQ.XNAS-RangeBreakoutStrategy-000                   O-20190919-235900-001-000-1150
#
#                                                    entry  side quantity  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000                    BUY  FLAT        0
#
#                                                    peak_qty  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...      124
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...      123
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...        8
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...        3
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...        5
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...      183
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...       71
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...       64
# NQ.XNAS-RangeBreakoutStrategy-000                       160
#
#                                                                    ts_opened  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06... 2019-08-21 20:37:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff... 2019-08-26 20:00:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6... 2019-08-27 19:03:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6... 2019-08-28 19:20:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184... 2019-09-02 22:55:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63... 2019-09-04 19:25:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600... 2019-09-10 20:01:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83... 2019-09-11 20:38:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000                  2019-09-16 20:03:00+00:00
#
#                                                                 ts_last  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  1566518340000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  1566863940000000000
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  1566950340000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  1567036740000000000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  1567468740000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  1567987140000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  1568159940000000000
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  1568332740000000000
# NQ.XNAS-RangeBreakoutStrategy-000                   1568937540000000000
#
#                                                                    ts_closed  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06... 2019-08-22 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff... 2019-08-26 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6... 2019-08-27 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6... 2019-08-28 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184... 2019-09-02 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63... 2019-09-08 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600... 2019-09-10 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83... 2019-09-12 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000                  2019-09-19 23:59:00+00:00
#
#                                                         duration_ns  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   98520000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...   14340000000000
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...   17760000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...   16740000000000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...    3840000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  362040000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   14280000000000
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   98460000000000
# NQ.XNAS-RangeBreakoutStrategy-000                   273360000000000
#
#                                                           avg_px_open  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  7746.185483870968
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  7589.477642276423
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...         7599.15625
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  7601.583333333333
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...             7641.5
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...   7873.32865864071
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   7815.68661971831
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...             7923.5
# NQ.XNAS-RangeBreakoutStrategy-000                   7895.225422664665
#
#                                                          avg_px_close  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...          7768.6675
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  7572.741138211382
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...             7587.5
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...             7580.0
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...            7627.25
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  7774.926523297491
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  7811.741126760563
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...         7953.13625
# NQ.XNAS-RangeBreakoutStrategy-000                   7880.182737306844
#
#                                                      commissions  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000                   ['0.00 USD']
#
#                                                    realized_return  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...          0.0029
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...        -0.00221
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...        -0.00153
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...        -0.00284
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...        -0.00186
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...         -0.0125
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...         -0.0005
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...         0.00374
# NQ.XNAS-RangeBreakoutStrategy-000                         -0.00191
#
#                                                     realized_pnl
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   -165.57 USD
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  -2058.59 USD
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...    -93.25 USD
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...    -64.75 USD
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...    -71.25 USD
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...    265.50 USD
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   -280.13 USD
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   1896.72 USD
# NQ.XNAS-RangeBreakoutStrategy-000                   -1971.48 USD

# %%
account_report_df = engine.trader.generate_account_report(NASDAQ)
order_fills_report_df = engine.trader.generate_order_fills_report()
positions_report_df = engine.trader.generate_positions_report()
positions_report_df
# Out:
#                                                          trader_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  BACKTESTER-001
# NQ.XNAS-RangeBreakoutStrategy-000                   BACKTESTER-001
#
#                                                                   strategy_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  RangeBreakoutStrategy-000
# NQ.XNAS-RangeBreakoutStrategy-000                   RangeBreakoutStrategy-000
#
#                                                    instrument_id account_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...       NQ.XNAS   XNAS-001
# NQ.XNAS-RangeBreakoutStrategy-000                        NQ.XNAS   XNAS-001
#
#                                                                  opening_order_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...    O-20190821-203700-001-000-1
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  O-20190826-200000-001-000-131
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  O-20190827-190300-001-000-255
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  O-20190828-192000-001-000-264
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  O-20190902-225500-001-000-268
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  O-20190904-192500-001-000-274
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  O-20190910-200100-001-000-556
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  O-20190911-203800-001-000-628
# NQ.XNAS-RangeBreakoutStrategy-000                   O-20190916-200300-001-000-694
#
#                                                                   closing_order_id  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   O-20190822-235900-001-000-130
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...   O-20190826-235900-001-000-254
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...   O-20190827-235900-001-000-263
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...   O-20190828-235900-001-000-267
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...   O-20190902-235900-001-000-273
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...   O-20190908-235900-001-000-555
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   O-20190910-235900-001-000-627
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   O-20190912-235900-001-000-693
# NQ.XNAS-RangeBreakoutStrategy-000                   O-20190919-235900-001-000-1150
#
#                                                    entry  side quantity  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   BUY  FLAT        0
# NQ.XNAS-RangeBreakoutStrategy-000                    BUY  FLAT        0
#
#                                                    peak_qty  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...      124
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...      123
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...        8
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...        3
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...        5
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...      183
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...       71
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...       64
# NQ.XNAS-RangeBreakoutStrategy-000                       160
#
#                                                                    ts_opened  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06... 2019-08-21 20:37:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff... 2019-08-26 20:00:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6... 2019-08-27 19:03:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6... 2019-08-28 19:20:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184... 2019-09-02 22:55:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63... 2019-09-04 19:25:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600... 2019-09-10 20:01:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83... 2019-09-11 20:38:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000                  2019-09-16 20:03:00+00:00
#
#                                                                 ts_last  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  1566518340000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  1566863940000000000
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  1566950340000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  1567036740000000000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  1567468740000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  1567987140000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  1568159940000000000
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  1568332740000000000
# NQ.XNAS-RangeBreakoutStrategy-000                   1568937540000000000
#
#                                                                    ts_closed  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06... 2019-08-22 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff... 2019-08-26 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6... 2019-08-27 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6... 2019-08-28 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184... 2019-09-02 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63... 2019-09-08 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600... 2019-09-10 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83... 2019-09-12 23:59:00+00:00
# NQ.XNAS-RangeBreakoutStrategy-000                  2019-09-19 23:59:00+00:00
#
#                                                         duration_ns  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   98520000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...   14340000000000
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...   17760000000000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...   16740000000000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...    3840000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  362040000000000
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   14280000000000
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   98460000000000
# NQ.XNAS-RangeBreakoutStrategy-000                   273360000000000
#
#                                                           avg_px_open  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  7746.185483870968
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  7589.477642276423
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...         7599.15625
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  7601.583333333333
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...             7641.5
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...   7873.32865864071
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   7815.68661971831
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...             7923.5
# NQ.XNAS-RangeBreakoutStrategy-000                   7895.225422664665
#
#                                                          avg_px_close  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...          7768.6675
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  7572.741138211382
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...             7587.5
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...             7580.0
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...            7627.25
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  7774.926523297491
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  7811.741126760563
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...         7953.13625
# NQ.XNAS-RangeBreakoutStrategy-000                   7880.182737306844
#
#                                                      commissions  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  ['0.00 USD']
# NQ.XNAS-RangeBreakoutStrategy-000                   ['0.00 USD']
#
#                                                    realized_return  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...          0.0029
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...        -0.00221
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...        -0.00153
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...        -0.00284
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...        -0.00186
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...         -0.0125
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...         -0.0005
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...         0.00374
# NQ.XNAS-RangeBreakoutStrategy-000                         -0.00191
#
#                                                     realized_pnl
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...   -165.57 USD
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  -2058.59 USD
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...    -93.25 USD
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...    -64.75 USD
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...    -71.25 USD
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...    265.50 USD
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...   -280.13 USD
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...   1896.72 USD
# NQ.XNAS-RangeBreakoutStrategy-000                   -1971.48 USD

# %%
positions_report_df['avg_px_open'] = pd.to_numeric(positions_report_df['avg_px_open'], errors='coerce')
positions_report_df['avg_px_close'] = pd.to_numeric(positions_report_df['avg_px_close'], errors='coerce')
positions_report_df['realized_pnl'] = pd.to_numeric(positions_report_df['realized_pnl'].str.replace(' USD', ''), errors='coerce')

# Create new DataFrame with required columns
new_df = pd.DataFrame()
new_df['Entry price'] = positions_report_df['avg_px_open']
new_df['Exit price'] = positions_report_df['avg_px_close']
new_df['Net Profit'] = positions_report_df['realized_pnl']

# Calculate cumulative net profit
new_df['Cum Net Profit'] = new_df['Net Profit'].cumsum()

# Calculate drawdown as the difference from the running max Cum Net Profit
new_df['Drawdown'] = new_df['Cum Net Profit'] - new_df['Cum Net Profit'].cummax()

# Calculate net profit and max drawdown
net_profit = new_df['Net Profit'].sum()
max_drawdown = new_df['Drawdown'].min()

# Output the new DataFrame and calculated values
print(f"Net Profit: {net_profit}")
print(f"Max Drawdown: {max_drawdown}")
new_df
# Out:
# Net Profit: -2542.8
# Max Drawdown: -2377.23
#                                                     Entry price   Exit price  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...  7746.185484  7768.667500
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...  7589.477642  7572.741138
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...  7599.156250  7587.500000
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...  7601.583333  7580.000000
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...  7641.500000  7627.250000
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...  7873.328659  7774.926523
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...  7815.686620  7811.741127
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...  7923.500000  7953.136250
# NQ.XNAS-RangeBreakoutStrategy-000                   7895.225423  7880.182737
#
#                                                     Net Profit  \
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...     -165.57
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...    -2058.59
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...      -93.25
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...      -64.75
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...      -71.25
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...      265.50
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...     -280.13
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...     1896.72
# NQ.XNAS-RangeBreakoutStrategy-000                     -1971.48
#
#                                                     Cum Net Profit  Drawdown
# position_id
# NQ.XNAS-RangeBreakoutStrategy-000-0c082c39-6e06...         -165.57      0.00
# NQ.XNAS-RangeBreakoutStrategy-000-aeb1bc96-23ff...        -2224.16  -2058.59
# NQ.XNAS-RangeBreakoutStrategy-000-09ea2547-b8d6...        -2317.41  -2151.84
# NQ.XNAS-RangeBreakoutStrategy-000-aa0184a8-e8f6...        -2382.16  -2216.59
# NQ.XNAS-RangeBreakoutStrategy-000-bb1bc3a9-b184...        -2453.41  -2287.84
# NQ.XNAS-RangeBreakoutStrategy-000-d66c16d3-9d63...        -2187.91  -2022.34
# NQ.XNAS-RangeBreakoutStrategy-000-d0b1ccf1-4600...        -2468.04  -2302.47
# NQ.XNAS-RangeBreakoutStrategy-000-a826f29f-1c83...         -571.32   -405.75
# NQ.XNAS-RangeBreakoutStrategy-000                         -2542.80  -2377.23
